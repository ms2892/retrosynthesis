# %%
from split_environment import *
from agents import *

import rdkit
from rdkit import Chem

# %%
smiles = 'CC(C)CON=C(C(=O)NC1C(=O)N2C(C(=O)O)=CCS[C@H]12)c1csc(N)n1'

# %%
randAgent = RandomAgent()

# %%
equalAgent = EqualSplitAgent()

# %%
bonds = randAgent.action(smiles)
print(bonds)
# Out:
# [[5, 6]]

# %%
mols = break_bond(Chem.MolFromSmiles(smiles),bonds)

# %%
mols
# Out:
# [<rdkit.Chem.rdchem.Mol at 0x7f5df9966c70>,
#  <rdkit.Chem.rdchem.Mol at 0x7f5df9966ce0>]

# %%
for i in mols:
    display(i)

# %%
bond = equalAgent.action(smiles)
# Out:
# [14:06:37] non-ring atom 22 marked aromatic
# [14:06:37] non-ring atom 22 marked aromatic
# [14:06:37] non-ring atom 22 marked aromatic
# [14:06:37] non-ring atom 22 marked aromatic
# [14:06:37] non-ring atom 22 marked aromatic

# %%
bond
# Out:
# [[6, 7]]

# %%
mols = break_bond(Chem.MolFromSmiles(smiles),bond)

# %%
for i in mols:
    display(i)
